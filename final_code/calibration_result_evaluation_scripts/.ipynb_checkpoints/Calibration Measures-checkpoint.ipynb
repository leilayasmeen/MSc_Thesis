# %% [markdown]
# # Calibration

# %% [markdown]
# Evaluating calibration methods on convolutional neural networks.

# %%
import numpy as np
import pandas as pd
from os.path import join
from sklearn.isotonic import IsotonicRegression
from sklearn.linear_model import LogisticRegression
from cal_methods import TemperatureScaling, evaluate, softmax, cal_results
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Paths to files with logits.

# %%
PATH = '/Users/wildflowerlyi/Desktop/Github/NN_calibration/'
files = ('resnet_cifar/probs_resnet110_c10clip_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_augmean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_2250mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_1125mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_560mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_2250_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_1125_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_560_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol2mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol2_2250mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol2_1125mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol2_560mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol2_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol2_2250_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol2_1125_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol2_560_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol3mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol3_2250mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol3_1125mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol3_560mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol3_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol3_2250_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol3_1125_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol3_560_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol4mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol4_2250mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol4_1125mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol4_560mean_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol4_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol4_2250_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol4_1125_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_interpol4_560_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixupalpha1_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixupalpha06_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixupalpha04_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixup_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixupalpha01_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixupalpha005_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixup_varyprop_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixup_varyprop2250_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixup_varyprop1125_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixup_varyprop560_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_augmean_beta_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_2250mean_beta_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_1125mean_beta_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug_560mean_beta_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug3mean_beta_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug3_2250mean_beta_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug3_1125mean_beta_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_aug3_560mean_beta_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_augmean_beta_largesample_45000_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_augmean_beta_largesample_22500_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_augmean_beta_largesample_11250_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_augmean_beta_largesample_5625_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_augmean_beta_largesample_4500_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_augmean_beta_largesample_2250_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_augmean_beta_largesample_1125_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_augmean_beta_largesample_560_logits.p'
         #,'resnet_cifar/probs_resnet110_c10clip_mixup_baseline_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixup_largesample_baseline_22500_logits.p'
         #,'resnet_cifar/probs_resnet110_c10clip_mixup_baseline_11250_logits.p'
         #,'resnet_cifar/probs_resnet110_c10clip_mixup_baseline_5625_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixup_baseline_4500_logits.p'
         #,'resnet_cifar/probs_resnet110_c10clip_mixup_baseline_2250_logits.p'
         ,'resnet_cifar/probs_resnet110_c10clip_mixup_baseline_1125_logits.p'
         #,'resnet_cifar/probs_resnet110_c10clip_mixup_baseline_560_logits.p'
        )

# %% [markdown]
# ### Isotonic Regression

# %%
df_iso = cal_results(IsotonicRegression, PATH, files, {'y_min':0, 'y_max':1}, approach = "single")
# Out:
# cifar/probs_resnet110_c10clip
# ('Accuracy:', 93.43)
# ('Error:', 6.569999999999993)
# ('ECE:', 0.04945112048983577)
# ('MCE:', 0.3290730118751526)
# ('Loss:', 0.37601464391059347)
# cifar/probs_resnet110_c10clip_augmean
# ('Accuracy:', 93.01)
# ('Error:', 6.989999999999995)
# ('ECE:', 0.04638580127060413)
# ('MCE:', 0.32111917436122894)
# ('Loss:', 0.3885267087939526)
# cifar/probs_resnet110_c10clip_aug_2250mean
# ('Accuracy:', 92.69)
# ('Error:', 7.310000000000002)
# ('ECE:', 0.05112848895192146)
# ('MCE:', 0.3638733774423599)
# ('Loss:', 0.37633696130207867)
# cifar/probs_resnet110_c10clip_aug_1125mean
# ('Accuracy:', 92.82000000000001)
# ('Error:', 7.179999999999993)
# ('ECE:', 0.05065809172987938)
# ('MCE:', 0.33941681563854215)
# ('Loss:', 0.3812145050069002)
# cifar/probs_resnet110_c10clip_aug_560mean
# ('Accuracy:', 93.27)
# ('Error:', 6.730000000000004)
# ('ECE:', 0.04739113273620607)
# ('MCE:', 0.27788410355283333)
# ('Loss:', 0.3663087175342839)
# cifar/probs_resnet110_c10clip_aug
# ('Accuracy:', 92.47999999999999)
# ('Error:', 7.52000000000001)
# ('ECE:', 0.04956610566973679)
# ('MCE:', 0.25361686696608854)
# ('Loss:', 0.3935112272304268)
# cifar/probs_resnet110_c10clip_aug_2250
# ('Accuracy:', 92.74)
# ('Error:', 7.260000000000005)
# ('ECE:', 0.050032472711801466)
# ('MCE:', 0.31580235502299137)
# ('Loss:', 0.39963603362636424)
# cifar/probs_resnet110_c10clip_aug_1125
# ('Accuracy:', 92.94)
# ('Error:', 7.060000000000002)
# ('ECE:', 0.048366537040472016)
# ('MCE:', 0.2825258314609528)
# ('Loss:', 0.37671001177225516)
# cifar/probs_resnet110_c10clip_aug_560
# ('Accuracy:', 93.28999999999999)
# ('Error:', 6.710000000000008)
# ('ECE:', 0.04731794575452813)
# ('MCE:', 0.2996928063943425)
# ('Loss:', 0.3658179164649823)
# cifar/probs_resnet110_c10clip_aug_interpol2mean
# ('Accuracy:', 92.97)
# ('Error:', 7.030000000000001)
# ('ECE:', 0.05002679687142372)
# ('MCE:', 0.2671128809452057)
# ('Loss:', 0.3891552513887124)
# cifar/probs_resnet110_c10clip_aug_interpol2_2250mean
# ('Accuracy:', 93.19)
# ('Error:', 6.810000000000002)
# ('ECE:', 0.04939996947646139)
# ('MCE:', 0.30672075512172936)
# ('Loss:', 0.39536335205722506)

# %% [markdown]
# ### Temperature scaling

# %%
df_temp_scale = cal_results(TemperatureScaling, PATH, files, approach = "all")

# %% [markdown]
# #### Calibrated scores for CIFAR datasets.

# %%
df_iso

# %%
df_temp_scale

# %% [markdown]
# ## Dataframe with results

# %%
dfs = [df_iso, df_temp_scale]
names = ["Name", "Uncalibrated", "Isotonic Regression", "Temperature Scaling"]


def get_dataframe(dfs, column, names):

    df_res = pd.DataFrame(columns=names)

    for i in range(1, len(df_iso), 2):

        name = dfs[0].iloc[i-1]["Name"] # Get name of method
        uncalibrated = dfs[0].iloc[i-1][column]  # Get uncalibrated score

        row = [name, uncalibrated]  # Add scores to row

        for df in dfs:
            row.append(df.iloc[i][column])

        df_res.loc[(i-1)//2] = row
    
    df_res.set_index('Name', inplace = True)
        
    return df_res

# %%
df_error = get_dataframe(dfs, "Error", names)
df_ece = get_dataframe(dfs, "ECE", names)
df_mce = get_dataframe(dfs, "MCE", names)
df_loss = get_dataframe(dfs, "Loss", names)

# %%
print(df_error.iloc[:,0])
# Out:
# Name
# cifar/probs_resnet110_c10clip                                      6.57
# cifar/probs_resnet110_c10clip_augmean                              6.99
# cifar/probs_resnet110_c10clip_aug_2250mean                         7.31
# cifar/probs_resnet110_c10clip_aug_1125mean                         7.18
# cifar/probs_resnet110_c10clip_aug_560mean                          6.73
# cifar/probs_resnet110_c10clip_aug                                  7.52
# cifar/probs_resnet110_c10clip_aug_2250                             7.26
# cifar/probs_resnet110_c10clip_aug_1125                             7.06
# cifar/probs_resnet110_c10clip_aug_560                              6.71
# cifar/probs_resnet110_c10clip_aug_interpol2mean                    7.03
# cifar/probs_resnet110_c10clip_aug_interpol2_2250mean               6.81
# cifar/probs_resnet110_c10clip_aug_interpol2_1125mean               6.75
# cifar/probs_resnet110_c10clip_aug_interpol2_560mean                6.93
# cifar/probs_resnet110_c10clip_aug_interpol2                        7.17
# cifar/probs_resnet110_c10clip_aug_interpol2_2250                   7.28
# cifar/probs_resnet110_c10clip_aug_interpol2_1125                   6.84
# cifar/probs_resnet110_c10clip_aug_interpol2_560                    6.85
# cifar/probs_resnet110_c10clip_aug_interpol3mean                    7.60
# cifar/probs_resnet110_c10clip_aug_interpol3_2250mean               7.15
# cifar/probs_resnet110_c10clip_aug_interpol3_1125mean               7.25
# cifar/probs_resnet110_c10clip_aug_interpol3_560mean                7.01
# cifar/probs_resnet110_c10clip_aug_interpol3                        7.47
# cifar/probs_resnet110_c10clip_aug_interpol3_2250                   7.20
# cifar/probs_resnet110_c10clip_aug_interpol3_1125                   6.92
# cifar/probs_resnet110_c10clip_aug_interpol3_560                    6.86
# cifar/probs_resnet110_c10clip_aug_interpol4mean                    6.67
# cifar/probs_resnet110_c10clip_aug_interpol4_2250mean               7.25
# cifar/probs_resnet110_c10clip_aug_interpol4_1125mean               7.31
# cifar/probs_resnet110_c10clip_aug_interpol4_560mean                6.86
# cifar/probs_resnet110_c10clip_aug_interpol4                        6.73
#                                                                   ...
# cifar/probs_resnet110_c10clip_aug_interpol4_560                    6.68
# cifar/probs_resnet110_c10clip_mixupalpha1                          5.86
# cifar/probs_resnet110_c10clip_mixupalpha06                         5.78
# cifar/probs_resnet110_c10clip_mixupalpha04                         6.11
# cifar/probs_resnet110_c10clip_mixup                                5.97
# cifar/probs_resnet110_c10clip_mixupalpha01                         5.90
# cifar/probs_resnet110_c10clip_mixupalpha005                        6.25
# cifar/probs_resnet110_c10clip_mixup_varyprop                      31.75
# cifar/probs_resnet110_c10clip_mixup_varyprop2250                  20.76
# cifar/probs_resnet110_c10clip_mixup_varyprop1125                  10.15
# cifar/probs_resnet110_c10clip_mixup_varyprop560                    7.10
# cifar/probs_resnet110_c10clip_augmean_beta                         7.34
# cifar/probs_resnet110_c10clip_aug_2250mean_beta                    6.88
# cifar/probs_resnet110_c10clip_aug_1125mean_beta                    6.66
# cifar/probs_resnet110_c10clip_aug_560mean_beta                     6.86
# cifar/probs_resnet110_c10clip_aug3mean_beta                        8.49
# cifar/probs_resnet110_c10clip_aug3_2250mean_beta                   7.71
# cifar/probs_resnet110_c10clip_aug3_1125mean_beta                   7.29
# cifar/probs_resnet110_c10clip_aug3_560mean_beta                    7.08
# cifar/probs_resnet110_c10clip_augmean_beta_largesample_45000       9.76
# cifar/probs_resnet110_c10clip_augmean_beta_largesample_22500       8.15
# cifar/probs_resnet110_c10clip_augmean_beta_largesample_11250       7.19
# cifar/probs_resnet110_c10clip_augmean_beta_largesample_5625        6.87
# cifar/probs_resnet110_c10clip_augmean_beta_largesample_4500        7.10
# cifar/probs_resnet110_c10clip_augmean_beta_largesample_2250        6.80
# cifar/probs_resnet110_c10clip_augmean_beta_largesample_1125        6.48
# cifar/probs_resnet110_c10clip_augmean_beta_largesample_560         6.66
# cifar/probs_resnet110_c10clip_mixup_largesample_baseline_22500     7.00
# cifar/probs_resnet110_c10clip_mixup_baseline_4500                  6.99
# cifar/probs_resnet110_c10clip_mixup_baseline_1125                  6.67
# Name: Uncalibrated, Length: 62, dtype: float64

# %%
df_ece.iloc[43:47, 0]
# Out:
# Name
# cifar/probs_resnet110_c10clip_augmean_beta         0.053234
# cifar/probs_resnet110_c10clip_aug_2250mean_beta    0.048455
# cifar/probs_resnet110_c10clip_aug_1125mean_beta    0.046617
# cifar/probs_resnet110_c10clip_aug_560mean_beta     0.049521
# Name: Uncalibrated, dtype: float64

# %%
# Plots to illustrate SLI and mixup results by the number of pairs, for beta lambda (largesample)

import matplotlib.pyplot as plt
import numpy as np

numpairs = np.array([560, 1125, 2250, 4500, 5625, 11250, 22500, 45000])
numpairsmixup = np.array([1125, 4500, 22500])
ecelargesample = df_ece.iloc[51:59, 1]
mcelargesample = df_mce.iloc[51:59, 1]
losslargesample = df_loss.iloc[51:59, 1]
errorlargesample = df_error.iloc[51:59, 1]
ecelargesamplemixup = df_ece.iloc[59:62, 1]
mcelargesamplemixup = df_mce.iloc[59:62, 1]
losslargesamplemixup = df_loss.iloc[59:62, 1]
errorlargesamplemixup = df_error.iloc[59:62, 1]

# style
plt.style.use('seaborn-whitegrid')
 
# create a color palette
palette = plt.get_cmap('Set1')

# Plot ECE 
plt.figure(1)
plt.plot(numpairs, ecelargesample, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='Latent Blending')

# Add legend and labels
#plt.legend(loc='best')
plt.title("ECE by No. of Pairs", fontsize=12, fontweight=0, color='black')
plt.xlabel("No. of Pairs")
plt.ylabel("ECE")

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/largesampleecebypairs.png')

# Plot MCE 
plt.figure(2)
plt.plot(numpairs, mcelargesample, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='Latent Blending')

# Add legend and labels
#plt.legend(loc='best')
plt.title("MCE by No. of Pairs", fontsize=12, fontweight=0, color='black')
plt.xlabel("No. of Pairs")
plt.ylabel("MCE")

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/largesamplemcebypairs.png')

# Plot error
plt.figure(3)
plt.plot(numpairs, errorlargesample, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='Latent Blending')

# Add legend and labels
#plt.legend(loc='best')
plt.title("Error by No. of Pairs", fontsize=12, fontweight=0, color='black')
plt.xlabel("No. of Pairs")
plt.ylabel("Error (%)")

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/largesampleerrorbypairs.png')

# Plot loss 
plt.figure(4)
plt.plot(numpairs, losslargesample, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='Latent Blending')

# Add legend and labels
#plt.legend(loc='best')
plt.title("Loss by No. of Pairs", fontsize=12, fontweight=0, color='black')
plt.xlabel("No. of Pairs")
plt.ylabel("Loss")

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/largesamplelossbypairs.png')

# %%
# Plots to illustrate SLI results against the baseline by number of pairs, for uniform lambda

import matplotlib.pyplot as plt
import numpy as np

numpairs = np.array([560, 1125, 2250, 4500])

# style
plt.style.use('seaborn-whitegrid')
 
# create a color palette
palette = plt.get_cmap('Set1')

# Plot ECE for mixup by alpha value
eceuniformaugmean1 = df_ece.iloc[1:5, 1]
eceuniformaugmean2 = df_ece.iloc[9:13, 1]
eceuniformaugmean3 = df_ece.iloc[17:21, 1]
eceuniformaugmean4 = df_ece.iloc[25:29, 1]

plt.figure(1)
plt.plot(numpairs, eceuniformaugmean1, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='SLI')
plt.plot(numpairs, eceuniformaugmean2, markerfacecolor='blue', markersize=12, color=palette(2), linewidth=4, label='SLI-CP')
plt.plot(numpairs, eceuniformaugmean3, markerfacecolor='blue', markersize=12, color=palette(3), linewidth=4, label='Slerp')
plt.plot(numpairs, eceuniformaugmean4, markerfacecolor='blue', markersize=12, color=palette(4), linewidth=4, label='Slerp-CP')

# Add legend and labels
plt.legend(loc='best')
plt.title("ECE by No. of Pairs", fontsize=12, fontweight=0, color='black')
plt.xlabel("No. of Pairs")
plt.ylabel("ECE")
plt.xlim(500, 4500)
plt.ylim(0.009, 0.017)

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/uniformecebypairs.png')

# Plot MCE for mixup by alpha value
mceuniformaugmean1 = df_mce.iloc[1:5, 1]
mceuniformaugmean2 = df_mce.iloc[9:13, 1]
mceuniformaugmean3 = df_mce.iloc[17:21, 1]
mceuniformaugmean4 = df_mce.iloc[25:29, 1]

plt.figure(2)
plt.plot(numpairs, mceuniformaugmean1, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='SLI')
plt.plot(numpairs, mceuniformaugmean2, markerfacecolor='blue', markersize=12, color=palette(2), linewidth=4, label='SLI-CP')
plt.plot(numpairs, mceuniformaugmean3, markerfacecolor='blue', markersize=12, color=palette(3), linewidth=4, label='Slerp')
plt.plot(numpairs, mceuniformaugmean4, markerfacecolor='blue', markersize=12, color=palette(4), linewidth=4, label='Slerp-CP')

# Add legend and labels
#plt.legend(loc='best')
plt.title("MCE by No. of Pairs", fontsize=12, fontweight=0, color='black')
plt.xlabel("No. of Pairs")
plt.ylabel("MCE")
plt.xlim(500, 4500)

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/uniformmcebypairs.png')

# Plot Error for mixup by alpha value
erroruniformaugmean1 = df_error.iloc[1:5, 1]
erroruniformaugmean2 = df_error.iloc[9:13, 1]
erroruniformaugmean3 = df_error.iloc[17:21, 1]
erroruniformaugmean4 = df_error.iloc[25:29, 1]

plt.figure(3)
plt.plot(numpairs, erroruniformaugmean1, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='SLI')
plt.plot(numpairs, erroruniformaugmean2, markerfacecolor='blue', markersize=12, color=palette(2), linewidth=4, label='SLI-CP')
plt.plot(numpairs, erroruniformaugmean3, markerfacecolor='blue', markersize=12, color=palette(3), linewidth=4, label='Slerp')
plt.plot(numpairs, erroruniformaugmean4, markerfacecolor='blue', markersize=12, color=palette(4), linewidth=4, label='Slerp-CP')

# Add legend and labels
plt.legend(loc='best')
plt.title("Error by No. of Pairs", fontsize=12, fontweight=0, color='black')
plt.xlabel("No. of Pairs")
plt.ylabel("Error")
plt.xlim(500, 4500)
plt.ylim(6.8,7.6)

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/uniformerrorbypairs.png')

# Plot Loss for mixup by alpha value
lossuniformaugmean1 = df_loss.iloc[1:5, 1]
lossuniformaugmean2 = df_loss.iloc[9:13, 1]
lossuniformaugmean3 = df_loss.iloc[17:21, 1]
lossuniformaugmean4 = df_loss.iloc[25:29, 1]

plt.figure(4)
plt.plot(numpairs, lossuniformaugmean1, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='SLI')
plt.plot(numpairs, lossuniformaugmean2, markerfacecolor='blue', markersize=12, color=palette(2), linewidth=4, label='SLI-CP')
plt.plot(numpairs, lossuniformaugmean3, markerfacecolor='blue', markersize=12, color=palette(3), linewidth=4, label='Slerp')
plt.plot(numpairs, lossuniformaugmean4, markerfacecolor='blue', markersize=12, color=palette(4), linewidth=4, label='Slerp-CP')

# Add legend and labels
plt.legend(loc='best')
plt.title("Loss by No. of Pairs", fontsize=12, fontweight=0, color='black')
plt.xlabel("No. of Pairs")
plt.ylabel("Loss")
plt.xlim(500, 4500)

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/uniformlossbypairs.png')

# %%
# Plots to illustrate SLI results against the baseline by number of pairs, for beta lambda

import matplotlib.pyplot as plt
import numpy as np

numpairs = np.array([560, 1125, 2250, 4500])

# style
plt.style.use('seaborn-whitegrid')
 
# create a color palette
palette = plt.get_cmap('Set1')

# Plot ECE for mixup by alpha value
ecebetaaugmean1 = df_ece.iloc[43:47, 1]
ecebetaaugmean3 = df_ece.iloc[47:51, 1]

plt.figure(1)
plt.plot(numpairs, ecebetaaugmean1, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='SLI')
plt.plot(numpairs, ecebetaaugmean3, markerfacecolor='blue', markersize=12, color=palette(3), linewidth=4, label='Slerp')

# Add legend and labels
plt.legend(loc='best')
plt.title("ECE by No. of Pairs", fontsize=12, fontweight=0, color='black')
plt.xlabel("No. of Pairs")
plt.ylabel("ECE")
plt.xlim(500,4500)

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/betaecebypairs.png')

# Plot MCE for mixup by alpha value
mcebetaaugmean1 = df_mce.iloc[43:47, 1]
mcebetaaugmean3 = df_mce.iloc[47:51, 1]

plt.figure(2)
plt.plot(numpairs, mcebetaaugmean1, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='SLI')
plt.plot(numpairs, mcebetaaugmean3, markerfacecolor='blue', markersize=12, color=palette(3), linewidth=4, label='Slerp')

# Add legend and labels
plt.legend(loc='best')
plt.title("MCE by No. of Pairs", fontsize=12, fontweight=0, color='black')
plt.xlabel("No. of Pairs")
plt.ylabel("MCE")
plt.xlim(500,4500)
plt.ylim(0.06,0.25)

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/betamcebypairs.png')

# Plot Error for mixup by alpha value
errorbetaaugmean1 = df_error.iloc[43:47, 1]
errorbetaaugmean3 = df_error.iloc[47:51, 1]

plt.figure(3)
plt.plot(numpairs, errorbetaaugmean1, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='SLI')
plt.plot(numpairs, errorbetaaugmean3, markerfacecolor='blue', markersize=12, color=palette(3), linewidth=4, label='Slerp')

# Add legend and labels
plt.legend(loc='best')
plt.title("Error by No. of Pairs", fontsize=12, fontweight=0, color='black')
plt.xlabel("No. of Pairs")
plt.ylabel("Error")
plt.xlim(500,4500)

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/betaerrorbypairs.png')

# Plot loss for mixup by alpha value
lossbetaaugmean1 = df_loss.iloc[43:47, 1]
lossbetaaugmean3 = df_loss.iloc[47:51, 1]

plt.figure(4)
plt.plot(numpairs, lossbetaaugmean1, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='SLI')
plt.plot(numpairs, lossbetaaugmean3, markerfacecolor='blue', markersize=12, color=palette(3), linewidth=4, label='Slerp')

# Add legend and labels
plt.legend(loc='best')
plt.title("Loss by No. of Pairs", fontsize=12, fontweight=0, color='black')
plt.xlabel("No. of Pairs")
plt.ylabel("Loss")
plt.xlim(500,4500)

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/betalossbypairs.png')

# %%
# Plots to illustrate results for mixup for various values of lambda

import matplotlib.pyplot as plt
import numpy as np

alphas = np.array([0.05, 0.1, 0.2, 0.4, 0.6, 1.0])
numpairs = np.array([560, 1125, 2250, 4500, 5625, 11250, 22500, 45000, 90000])
ecemixup = df_ece.iloc[33:39, 1]
mcemixup = df_mce.iloc[33:39, 1]
lossmixup = df_loss.iloc[33:39, 1]
errormixup = df_error.iloc[33:39, 1]

# style
plt.style.use('seaborn-whitegrid')
 
# create a color palette
palette = plt.get_cmap('Set1')

# Plot ECE for mixup by alpha value
plt.figure(1)
plt.plot(alphas, ecemixup, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='ECE')
plt.xlim(0.0, 1.0)
plt.ylim(0.0077, 0.013)

# Add legend and labels
#plt.legend(loc='best')
plt.title("ECE by Alpha, Mixup", fontsize=12, fontweight=0, color='black')
plt.xlabel("Alpha")
plt.ylabel("ECE")

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/mixupecebyalpha.png')

# Plot MCE for mixup by alpha value
plt.figure(2)
plt.plot(alphas, mcemixup, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='MCE')
plt.xlim(0.0, 1.0)
plt.plot(alphas, mcemixup, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='MCE')
plt.ylim(0.08, 0.35)

# Add legend and labels
#plt.legend(loc='best')
plt.title("MCE by Alpha, Mixup", fontsize=12, fontweight=0, color='black')
plt.xlabel("Alpha")
plt.ylabel("MCE")

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/mixupmcebyalpha.png')

# Plot error for mixup by alpha value
plt.figure(3)
plt.plot(alphas, errormixup, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='Error')


# Add legend and labels
#plt.legend(loc='best')
plt.title("Error by Alpha, Mixup", fontsize=12, fontweight=0, color='black')
plt.xlabel("Alpha")
plt.ylabel("Error (%)")
plt.xlim(0.0, 1.0)

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/mixuperrorbyalpha.png')

# Plot loss for mixup by alpha value
plt.figure(4)
plt.plot(alphas, lossmixup, markerfacecolor='blue', markersize=12, color=palette(1), linewidth=4, label='Loss')
plt.xlim(0.0, 1.0)

# Add legend and labels
#plt.legend(loc='best')
plt.title("Loss by Alpha, Mixup", fontsize=12, fontweight=0, color='black')
plt.xlabel("Alpha")
plt.ylabel("Loss")

# Plot
plt.savefig('/Users/wildflowerlyi/Desktop/Plots/mixuplossbyalpha.png')

# %% [markdown]
# ## Scores

# %%
def highlight_min(s):
    '''
    highlight the min in a Series yellow.
    '''
    is_max = s == s.min()
    return ['background-color: yellow' if v else '' for v in is_max]

# %% [markdown]
# ## Error Rate

# %%
df_error.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row0_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row1_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row1_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row2_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row3_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row3_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row4_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row4_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row5_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row6_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row6_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row7_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row7_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row8_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row8_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row9_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row10_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row10_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row11_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row11_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row12_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row13_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row13_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row14_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row15_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row16_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row16_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row17_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row18_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row18_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row19_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row19_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row20_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row21_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row21_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row22_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row22_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row23_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row24_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row24_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row25_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row25_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row26_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row27_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row28_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row28_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row29_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row30_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row31_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row31_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row32_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row33_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row33_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row34_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row34_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row35_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row35_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row36_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row36_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row37_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row37_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row38_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row38_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row39_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row40_col1 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row41_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row41_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row42_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row42_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row43_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row43_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row44_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row44_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row45_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row45_col2 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row46_col0 {
#             background-color:  yellow;
#         }    #T_2eb797a8_997c_11e8_a3f5_3c15c2e8e978row46_col2 {
#             background-color:

# %% [markdown]
# ## ECE

# %%
df_ece.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row0_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row1_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row2_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row3_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row4_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row5_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row6_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row7_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row8_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row9_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row10_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row11_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row12_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row13_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row14_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row15_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row16_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row17_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row18_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row19_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row20_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row21_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row22_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row23_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row24_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row25_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row26_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row27_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row28_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row29_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row30_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row31_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row32_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row33_col1 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row34_col1 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row35_col1 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row36_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row37_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row38_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row39_col1 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row40_col1 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row41_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row42_col1 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row43_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row44_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row45_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row46_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row47_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row48_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row49_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row50_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row51_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row52_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row53_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row54_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row55_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row56_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row57_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row58_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row59_col2 {
#             background-color:  yellow;
#         }    #T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row60_col2 {
#             background-color:  yellow;
#         }</style>
# <table id="T_2eca3ec7_997c_11e8_b759_3c15c2e8e978" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uncalibrated</th>
#         <th class="col_heading level0 col1" >Isotonic Regression</th>
#         <th class="col_heading level0 col2" >Temperature Scaling</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2eca3ec7_997c_11e8_b759_3c15c2e8e978level0_row0" class="row_heading level0 row0" >cifar/probs_resnet110_c10clip</th>
#         <td id="T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row0_col0" class="data row0 col0" >0.0494511</td>
#         <td id="T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row0_col1" class="data row0 col1" >0.0136369</td>
#         <td id="T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row0_col2" class="data row0 col2" >0.00966252</td>
#     </tr>    <tr>
#         <th id="T_2eca3ec7_997c_11e8_b759_3c15c2e8e978level0_row1" class="row_heading level0 row1" >cifar/probs_resnet110_c10clip_augmean</th>
#         <td id="T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row1_col0" class="data row1 col0" >0.0463858</td>
#         <td id="T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row1_col1" class="data row1 col1" >0.0133997</td>
#         <td id="T_2eca3ec7_997c_11e8_b759_3c15c2e8e978row1_col2" class="data row1 col2" >0.00813075</td>
#     </tr>    <tr>
#         <th id="T_2eca3ec7_997c_11e8_b759_3c15c2e8e978level0_row2" class="row_heading level0 row2" >cifar/probs_resnet110_c10clip_aug_2250mean</th>

# %% [markdown]
# ## MCE

# %%
df_mce.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row0_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row1_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row2_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row3_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row4_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row5_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row6_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row7_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row8_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row9_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row10_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row11_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row12_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row13_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row14_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row15_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row16_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row17_col0 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row18_col0 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row19_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row20_col0 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row21_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row22_col0 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row23_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row24_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row25_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row26_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row27_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row28_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row29_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row30_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row31_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row32_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row33_col0 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row34_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row35_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row36_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row37_col0 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row38_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row39_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row40_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row41_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row42_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row43_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row44_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row45_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row46_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row47_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row48_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row49_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row50_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row51_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row52_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row53_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row54_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row55_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row56_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row57_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row58_col1 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row59_col2 {
#             background-color:  yellow;
#         }    #T_2edd1b91_997c_11e8_b651_3c15c2e8e978row60_col2 {
#             background-color:  yellow;
#         }</style>
# <table id="T_2edd1b91_997c_11e8_b651_3c15c2e8e978" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uncalibrated</th>
#         <th class="col_heading level0 col1" >Isotonic Regression</th>
#         <th class="col_heading level0 col2" >Temperature Scaling</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2edd1b91_997c_11e8_b651_3c15c2e8e978level0_row0" class="row_heading level0 row0" >cifar/probs_resnet110_c10clip</th>
#         <td id="T_2edd1b91_997c_11e8_b651_3c15c2e8e978row0_col0" class="data row0 col0" >0.329073</td>
#         <td id="T_2edd1b91_997c_11e8_b651_3c15c2e8e978row0_col1" class="data row0 col1" >0.0982814</td>
#         <td id="T_2edd1b91_997c_11e8_b651_3c15c2e8e978row0_col2" class="data row0 col2" >0.132728</td>
#     </tr>    <tr>
#         <th id="T_2edd1b91_997c_11e8_b651_3c15c2e8e978level0_row1" class="row_heading level0 row1" >cifar/probs_resnet110_c10clip_augmean</th>
#         <td id="T_2edd1b91_997c_11e8_b651_3c15c2e8e978row1_col0" class="data row1 col0" >0.321119</td>
#         <td id="T_2edd1b91_997c_11e8_b651_3c15c2e8e978row1_col1" class="data row1 col1" >0.181916</td>
#         <td id="T_2edd1b91_997c_11e8_b651_3c15c2e8e978row1_col2" class="data row1 col2" >0.250516</td>
#     </tr>    <tr>
#         <th id="T_2edd1b91_997c_11e8_b651_3c15c2e8e978level0_row2" class="row_heading level0 row2" >cifar/probs_resnet110_c10clip_aug_2250mean</th>
#         <td

# %% [markdown]
# ## Loss

# %%
df_loss.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row0_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row1_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row2_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row3_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row4_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row5_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row6_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row7_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row8_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row9_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row10_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row11_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row12_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row13_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row14_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row15_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row16_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row17_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row18_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row19_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row20_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row21_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row22_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row23_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row24_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row25_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row26_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row27_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row28_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row29_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row30_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row31_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row32_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row33_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row34_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row35_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row36_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row37_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row38_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row39_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row40_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row41_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row42_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row43_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row44_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row45_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row46_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row47_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row48_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row49_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row50_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row51_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row52_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row53_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row54_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row55_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row56_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row57_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row58_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row59_col2 {
#             background-color:  yellow;
#         }    #T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row60_col2 {
#             background-color:  yellow;
#         }</style>
# <table id="T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uncalibrated</th>
#         <th class="col_heading level0 col1" >Isotonic Regression</th>
#         <th class="col_heading level0 col2" >Temperature Scaling</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978level0_row0" class="row_heading level0 row0" >cifar/probs_resnet110_c10clip</th>
#         <td id="T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row0_col0" class="data row0 col0" >0.376015</td>
#         <td id="T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row0_col1" class="data row0 col1" >0.277402</td>
#         <td id="T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row0_col2" class="data row0 col2" >0.21464</td>
#     </tr>    <tr>
#         <th id="T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978level0_row1" class="row_heading level0 row1" >cifar/probs_resnet110_c10clip_augmean</th>
#         <td id="T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row1_col0" class="data row1 col0" >0.388527</td>
#         <td id="T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row1_col1" class="data row1 col1" >0.351594</td>
#         <td id="T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978row1_col2" class="data row1 col2" >0.267974</td>
#     </tr>    <tr>
#         <th id="T_2ef0ee73_997c_11e8_ae46_3c15c2e8e978level0_row2" class="row_heading level0 row2" >cifar/probs_resnet110_c10clip_aug_2250mean</th>
#         <td id
