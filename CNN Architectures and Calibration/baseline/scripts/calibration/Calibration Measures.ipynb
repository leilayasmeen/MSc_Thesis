# %% [markdown]
# # Calibration

# %% [markdown]
# Evaluating calibration methods on convolutional neural networks.

# %%
import numpy as np
import pandas as pd
from os.path import join
from sklearn.isotonic import IsotonicRegression
from sklearn.linear_model import LogisticRegression
from cal_methods import TemperatureScaling, evaluate, softmax, cal_results
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Paths to files with logits.

# %%
PATH = '/Users/wildflowerlyi/Desktop/Github/NN_calibration/scripts'
files = ('resnet_cifar/probs_resnet110_c10_logits.p'
        , 'resnet_wide/probs_resnet_wide32_c10_logits.p'
        , 'resnet_densenet/probs_densenet40_c10_logits.p'
        #,'resnet_wide/probs_resnet_wide32_c10clip_logits.p'
        ,'resnet_wide/probs_resnet_wide32_c10clip_logits.p'
        ,'resnet_sd/probs_resnet110_SD_c10clip_logits.p'
        ,'resnet_densenet/probs_densenet40_c10clip_logits.p'
        #,'resnet_cifar/probs_resnet110_c100_logits.p'
        #,'resnet_wide/probs_resnet_wide32_c100_logits.p'
        #,'resnet_densenet/probs_densenet40_c100_logits.p'
        #,'resnet_wide/probs_resnet_wide32_c100clip_logits.p'    
        )

# %% [markdown]
# ### Isotonic Regression

# %%
df_iso = cal_results(IsotonicRegression, PATH, files, {'y_min':0, 'y_max':1}, approach = "single")
# Out:
# cifar/probs_resnet110_c10
# ('Accuracy:', 93.390000000000001)
# ('Error:', 6.6099999999999994)
# ('ECE:', 0.048270407003164296)
# ('MCE:', 0.379260828194109)
# ('Loss:', 0.38292819397349553)
# wide/probs_resnet_wide32_c10
# ('Accuracy:', 93.799999999999997)
# ('Error:', 6.2000000000000028)
# ('ECE:', 0.047311796060204525)
# ('MCE:', 0.3678059713045756)
# ('Loss:', 0.37100536326453859)
# densenet/probs_densenet40_c10
# ('Accuracy:', 92.900000000000006)
# ('Error:', 7.0999999999999943)
# ('ECE:', 0.051972183519601804)
# ('MCE:', 0.35494045674345875)
# ('Loss:', 0.41025025195239284)
# wide/probs_resnet_wide32_c10clip
# ('Accuracy:', 94.040000000000006)
# ('Error:', 5.9599999999999937)
# ('ECE:', 0.044856612253189064)
# ('MCE:', 0.31552806931237376)
# ('Loss:', 0.35969095881889424)
# sd/probs_resnet110_SD_c10clip
# ('Accuracy:', 17.66)
# ('Error:', 82.340000000000003)
# ('ECE:', 0.066272482181340464)
# ('MCE:', 0.81101521884286121)
# ('Loss:', 8.5405460218011964)
# densenet/probs_densenet40_c10clip
# ('Accuracy:', 93.109999999999999)
# ('Error:', 6.8900000000000006)
# ('ECE:', 0.050258812770247421)
# ('MCE:', 0.2948208893167561)
# ('Loss:', 0.40501787487553592)

# %% [markdown]
# ### Temperature scaling

# %%
df_temp_scale = cal_results(TemperatureScaling, PATH, files, approach = "all")
# Out:
# cifar/probs_resnet110_c10
# ('Accuracy:', 93.390000000000001)
# ('Error:', 6.6099999999999994)
# ('ECE:', 0.048270407003164296)
# ('MCE:', 0.379260828194109)
# ('Loss:', 0.38292819397349553)
# wide/probs_resnet_wide32_c10
# ('Accuracy:', 93.799999999999997)
# ('Error:', 6.2000000000000028)
# ('ECE:', 0.047311796060204525)
# ('MCE:', 0.3678059713045756)
# ('Loss:', 0.37100536326453859)
# densenet/probs_densenet40_c10
# ('Accuracy:', 92.900000000000006)
# ('Error:', 7.0999999999999943)
# ('ECE:', 0.051972183519601804)
# ('MCE:', 0.35494045674345875)
# ('Loss:', 0.41025025195239284)
# wide/probs_resnet_wide32_c10clip
# ('Accuracy:', 94.040000000000006)
# ('Error:', 5.9599999999999937)
# ('ECE:', 0.044856612253189064)
# ('MCE:', 0.31552806931237376)
# ('Loss:', 0.35969095881889424)
# sd/probs_resnet110_SD_c10clip
# ('Accuracy:', 17.66)
# ('Error:', 82.340000000000003)
# ('ECE:', 0.066272482181340464)
# ('MCE:', 0.81101521884286121)
# ('Loss:', 8.5405460218011964)
# densenet/probs_densenet40_c10clip
# ('Accuracy:', 93.109999999999999)
# ('Error:', 6.8900000000000006)
# ('ECE:', 0.050258812770247421)
# ('MCE:', 0.2948208893167561)
# ('Loss:', 0.40501787487553592)

# %% [markdown]
# #### Calibrated scores for CIFAR datasets.

# %%
df_iso
# Out:
#                                        Name  Error       ECE       MCE  \
# 0                 cifar/probs_resnet110_c10   6.61  0.048270  0.379261
# 1           cifar/probs_resnet110_c10_calib   6.82  0.012087  0.241357
# 2              wide/probs_resnet_wide32_c10   6.20  0.047312  0.367806
# 3        wide/probs_resnet_wide32_c10_calib   6.05  0.010466  0.083494
# 4             densenet/probs_densenet40_c10   7.10  0.051972  0.354940
# 5       densenet/probs_densenet40_c10_calib   7.10  0.012183  0.265471
# 6          wide/probs_resnet_wide32_c10clip   5.96  0.044857  0.315528
# 7    wide/probs_resnet_wide32_c10clip_calib   5.68  0.012156  0.186214
# 8             sd/probs_resnet110_SD_c10clip  82.34  0.066272  0.811015
# 9       sd/probs_resnet110_SD_c10clip_calib  77.30  0.063671  0.758553
# 10        densenet/probs_densenet40_c10clip   6.89  0.050259  0.294821
# 11  densenet/probs_densenet40_c10clip_calib   6.94  0.010380  0.115042
#
#         Loss
# 0   0.382928
# 1   0.282494
# 2   0.371005
# 3   0.217106
# 4   0.410250
# 5   0.281433
# 6   0.359691
# 7   0.232532
# 8   8.540546
# 9   2.222690
# 10  0.405018
# 11  0.272771

# %%
df_temp_scale
# Out:
#                                        Name  Error       ECE       MCE  \
# 0                 cifar/probs_resnet110_c10   6.61  0.048270  0.379261
# 1           cifar/probs_resnet110_c10_calib   6.61  0.007190  0.046223
# 2              wide/probs_resnet_wide32_c10   6.20  0.047312  0.367806
# 3        wide/probs_resnet_wide32_c10_calib   6.20  0.008058  0.251238
# 4             densenet/probs_densenet40_c10   7.10  0.051972  0.354940
# 5       densenet/probs_densenet40_c10_calib   7.10  0.009334  0.096582
# 6          wide/probs_resnet_wide32_c10clip   5.96  0.044857  0.315528
# 7    wide/probs_resnet_wide32_c10clip_calib   5.96  0.006065  0.242671
# 8             sd/probs_resnet110_SD_c10clip  82.34  0.066272  0.811015
# 9       sd/probs_resnet110_SD_c10clip_calib  14.34  0.009011  0.186850
# 10        densenet/probs_densenet40_c10clip   6.89  0.050259  0.294821
# 11  densenet/probs_densenet40_c10clip_calib   6.89  0.007119  0.055351
#
#         Loss
# 0   0.382928
# 1   0.220280
# 2   0.371005
# 3   0.186995
# 4   0.410250
# 5   0.216684
# 6   0.359691
# 7   0.185370
# 8   8.540546
# 9   0.423135
# 10  0.405018
# 11  0.209092

# %% [markdown]
# ## Dataframe with results

# %%
dfs = [df_iso, df_temp_scale]
names = ["Name", "Uncalibrated", "Isotonic Regression", "Temperature Scaling"]


def get_dataframe(dfs, column, names):

    df_res = pd.DataFrame(columns=names)

    for i in range(1, len(df_iso), 2):

        name = dfs[0].iloc[i-1]["Name"] # Get name of method
        uncalibrated = dfs[0].iloc[i-1][column]  # Get uncalibrated score

        row = [name, uncalibrated]  # Add scores to row

        for df in dfs:
            row.append(df.iloc[i][column])

        df_res.loc[(i-1)//2] = row
    
    df_res.set_index('Name', inplace = True)
        
    return df_res

# %%
df_error = get_dataframe(dfs, "Error", names)
df_ece = get_dataframe(dfs, "ECE", names)
df_mce = get_dataframe(dfs, "MCE", names)
df_loss = get_dataframe(dfs, "Loss", names)

# %% [markdown]
# ## Scores

# %%
def highlight_min(s):
    '''
    highlight the min in a Series yellow.
    '''
    is_max = s == s.min()
    return ['background-color: yellow' if v else '' for v in is_max]

# %% [markdown]
# ## Error Rate

# %%
df_error.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row0_col0 {
#             background-color:  yellow;
#         }    #T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row0_col2 {
#             background-color:  yellow;
#         }    #T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row1_col1 {
#             background-color:  yellow;
#         }    #T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row2_col0 {
#             background-color:  yellow;
#         }    #T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row2_col1 {
#             background-color:  yellow;
#         }    #T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row2_col2 {
#             background-color:  yellow;
#         }    #T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row3_col1 {
#             background-color:  yellow;
#         }    #T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row4_col2 {
#             background-color:  yellow;
#         }    #T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row5_col0 {
#             background-color:  yellow;
#         }    #T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row5_col2 {
#             background-color:  yellow;
#         }</style>
# <table id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uncalibrated</th>
#         <th class="col_heading level0 col1" >Isotonic Regression</th>
#         <th class="col_heading level0 col2" >Temperature Scaling</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978level0_row0" class="row_heading level0 row0" >cifar/probs_resnet110_c10</th>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row0_col0" class="data row0 col0" >6.61</td>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row0_col1" class="data row0 col1" >6.82</td>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row0_col2" class="data row0 col2" >6.61</td>
#     </tr>    <tr>
#         <th id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978level0_row1" class="row_heading level0 row1" >wide/probs_resnet_wide32_c10</th>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row1_col0" class="data row1 col0" >6.2</td>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row1_col1" class="data row1 col1" >6.05</td>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row1_col2" class="data row1 col2" >6.2</td>
#     </tr>    <tr>
#         <th id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978level0_row2" class="row_heading level0 row2" >densenet/probs_densenet40_c10</th>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row2_col0" class="data row2 col0" >7.1</td>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row2_col1" class="data row2 col1" >7.1</td>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row2_col2" class="data row2 col2" >7.1</td>
#     </tr>    <tr>
#         <th id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978level0_row3" class="row_heading level0 row3" >wide/probs_resnet_wide32_c10clip</th>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row3_col0" class="data row3 col0" >5.96</td>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row3_col1" class="data row3 col1" >5.68</td>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row3_col2" class="data row3 col2" >5.96</td>
#     </tr>    <tr>
#         <th id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978level0_row4" class="row_heading level0 row4" >sd/probs_resnet110_SD_c10clip</th>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row4_col0" class="data row4 col0" >82.34</td>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row4_col1" class="data row4 col1" >77.3</td>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row4_col2" class="data row4 col2" >14.34</td>
#     </tr>    <tr>
#         <th id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978level0_row5" class="row_heading level0 row5" >densenet/probs_densenet40_c10clip</th>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row5_col0" class="data row5 col0" >6.89</td>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row5_col1" class="data row5 col1" >6.94</td>
#         <td id="T_683d006e_6d7d_11e8_9b58_3c15c2e8e978row5_col2" class="data row5 col2" >6.89</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ## ECE

# %%
df_ece.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row0_col2 {
#             background-color:  yellow;
#         }    #T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row1_col2 {
#             background-color:  yellow;
#         }    #T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row2_col2 {
#             background-color:  yellow;
#         }    #T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row3_col2 {
#             background-color:  yellow;
#         }    #T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row4_col2 {
#             background-color:  yellow;
#         }    #T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row5_col2 {
#             background-color:  yellow;
#         }</style>
# <table id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uncalibrated</th>
#         <th class="col_heading level0 col1" >Isotonic Regression</th>
#         <th class="col_heading level0 col2" >Temperature Scaling</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978level0_row0" class="row_heading level0 row0" >cifar/probs_resnet110_c10</th>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row0_col0" class="data row0 col0" >0.0482704</td>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row0_col1" class="data row0 col1" >0.0120875</td>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row0_col2" class="data row0 col2" >0.00719009</td>
#     </tr>    <tr>
#         <th id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978level0_row1" class="row_heading level0 row1" >wide/probs_resnet_wide32_c10</th>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row1_col0" class="data row1 col0" >0.0473118</td>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row1_col1" class="data row1 col1" >0.0104662</td>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row1_col2" class="data row1 col2" >0.00805839</td>
#     </tr>    <tr>
#         <th id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978level0_row2" class="row_heading level0 row2" >densenet/probs_densenet40_c10</th>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row2_col0" class="data row2 col0" >0.0519722</td>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row2_col1" class="data row2 col1" >0.0121829</td>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row2_col2" class="data row2 col2" >0.00933419</td>
#     </tr>    <tr>
#         <th id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978level0_row3" class="row_heading level0 row3" >wide/probs_resnet_wide32_c10clip</th>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row3_col0" class="data row3 col0" >0.0448566</td>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row3_col1" class="data row3 col1" >0.0121559</td>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row3_col2" class="data row3 col2" >0.00606529</td>
#     </tr>    <tr>
#         <th id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978level0_row4" class="row_heading level0 row4" >sd/probs_resnet110_SD_c10clip</th>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row4_col0" class="data row4 col0" >0.0662725</td>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row4_col1" class="data row4 col1" >0.0636708</td>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row4_col2" class="data row4 col2" >0.00901112</td>
#     </tr>    <tr>
#         <th id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978level0_row5" class="row_heading level0 row5" >densenet/probs_densenet40_c10clip</th>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row5_col0" class="data row5 col0" >0.0502588</td>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row5_col1" class="data row5 col1" >0.0103795</td>
#         <td id="T_6844aa19_6d7d_11e8_89c7_3c15c2e8e978row5_col2" class="data row5 col2" >0.00711893</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ## MCE

# %%
df_mce.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row0_col2 {
#             background-color:  yellow;
#         }    #T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row1_col1 {
#             background-color:  yellow;
#         }    #T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row2_col2 {
#             background-color:  yellow;
#         }    #T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row3_col1 {
#             background-color:  yellow;
#         }    #T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row4_col2 {
#             background-color:  yellow;
#         }    #T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row5_col2 {
#             background-color:  yellow;
#         }</style>
# <table id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uncalibrated</th>
#         <th class="col_heading level0 col1" >Isotonic Regression</th>
#         <th class="col_heading level0 col2" >Temperature Scaling</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978level0_row0" class="row_heading level0 row0" >cifar/probs_resnet110_c10</th>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row0_col0" class="data row0 col0" >0.379261</td>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row0_col1" class="data row0 col1" >0.241357</td>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row0_col2" class="data row0 col2" >0.0462229</td>
#     </tr>    <tr>
#         <th id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978level0_row1" class="row_heading level0 row1" >wide/probs_resnet_wide32_c10</th>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row1_col0" class="data row1 col0" >0.367806</td>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row1_col1" class="data row1 col1" >0.0834937</td>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row1_col2" class="data row1 col2" >0.251238</td>
#     </tr>    <tr>
#         <th id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978level0_row2" class="row_heading level0 row2" >densenet/probs_densenet40_c10</th>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row2_col0" class="data row2 col0" >0.35494</td>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row2_col1" class="data row2 col1" >0.265471</td>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row2_col2" class="data row2 col2" >0.096582</td>
#     </tr>    <tr>
#         <th id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978level0_row3" class="row_heading level0 row3" >wide/probs_resnet_wide32_c10clip</th>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row3_col0" class="data row3 col0" >0.315528</td>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row3_col1" class="data row3 col1" >0.186214</td>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row3_col2" class="data row3 col2" >0.242671</td>
#     </tr>    <tr>
#         <th id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978level0_row4" class="row_heading level0 row4" >sd/probs_resnet110_SD_c10clip</th>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row4_col0" class="data row4 col0" >0.811015</td>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row4_col1" class="data row4 col1" >0.758553</td>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row4_col2" class="data row4 col2" >0.18685</td>
#     </tr>    <tr>
#         <th id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978level0_row5" class="row_heading level0 row5" >densenet/probs_densenet40_c10clip</th>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row5_col0" class="data row5 col0" >0.294821</td>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row5_col1" class="data row5 col1" >0.115042</td>
#         <td id="T_684a0e87_6d7d_11e8_bd09_3c15c2e8e978row5_col2" class="data row5 col2" >0.0553514</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ## Loss

# %%
df_loss.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row0_col2 {
#             background-color:  yellow;
#         }    #T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row1_col2 {
#             background-color:  yellow;
#         }    #T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row2_col2 {
#             background-color:  yellow;
#         }    #T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row3_col2 {
#             background-color:  yellow;
#         }    #T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row4_col2 {
#             background-color:  yellow;
#         }    #T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row5_col2 {
#             background-color:  yellow;
#         }</style>
# <table id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uncalibrated</th>
#         <th class="col_heading level0 col1" >Isotonic Regression</th>
#         <th class="col_heading level0 col2" >Temperature Scaling</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978level0_row0" class="row_heading level0 row0" >cifar/probs_resnet110_c10</th>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row0_col0" class="data row0 col0" >0.382928</td>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row0_col1" class="data row0 col1" >0.282494</td>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row0_col2" class="data row0 col2" >0.22028</td>
#     </tr>    <tr>
#         <th id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978level0_row1" class="row_heading level0 row1" >wide/probs_resnet_wide32_c10</th>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row1_col0" class="data row1 col0" >0.371005</td>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row1_col1" class="data row1 col1" >0.217106</td>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row1_col2" class="data row1 col2" >0.186995</td>
#     </tr>    <tr>
#         <th id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978level0_row2" class="row_heading level0 row2" >densenet/probs_densenet40_c10</th>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row2_col0" class="data row2 col0" >0.41025</td>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row2_col1" class="data row2 col1" >0.281433</td>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row2_col2" class="data row2 col2" >0.216684</td>
#     </tr>    <tr>
#         <th id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978level0_row3" class="row_heading level0 row3" >wide/probs_resnet_wide32_c10clip</th>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row3_col0" class="data row3 col0" >0.359691</td>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row3_col1" class="data row3 col1" >0.232532</td>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row3_col2" class="data row3 col2" >0.18537</td>
#     </tr>    <tr>
#         <th id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978level0_row4" class="row_heading level0 row4" >sd/probs_resnet110_SD_c10clip</th>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row4_col0" class="data row4 col0" >8.54055</td>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row4_col1" class="data row4 col1" >2.22269</td>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row4_col2" class="data row4 col2" >0.423135</td>
#     </tr>    <tr>
#         <th id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978level0_row5" class="row_heading level0 row5" >densenet/probs_densenet40_c10clip</th>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row5_col0" class="data row5 col0" >0.405018</td>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row5_col1" class="data row5 col1" >0.272771</td>
#         <td id="T_684f97ae_6d7d_11e8_ae79_3c15c2e8e978row5_col2" class="data row5 col2" >0.209092</td>
#     </tr></tbody>
# </table>
