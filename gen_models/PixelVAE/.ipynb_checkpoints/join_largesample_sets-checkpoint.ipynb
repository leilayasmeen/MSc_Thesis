# %%
import os, sys
sys.path.append(os.getcwd())

import random

import numpy as np
import tensorflow as tf
import imageio
from imageio import imsave

import keras

import time
import functools

import sklearn
from sklearn.model_selection import train_test_split

DATASET = 'cifar10' # mnist_256
SETTINGS = '32px_cifar' # mnist_256, 32px_small, 32px_big, 64px_small, 64px_big

OUT_DIR = '/Users/wildflowerlyi/Desktop/'

# %%
from keras.datasets import cifar10
N_CHANNELS = 3
HEIGHT = 32
WIDTH = 32
NUM_CLASSES = 10
(x_train_set, y_train_set), (x_test_set, y_test_set) = cifar10.load_data()
   
x_train_set = x_train_set.transpose(0,3,1,2)
x_test_set = x_test_set.transpose(0,3,1,2)
    
seed = 333
x_train_set, x_dev_set, y_train_set, y_dev_set = train_test_split(x_train_set, y_train_set, test_size=0.1, random_state=seed)

from keras.utils import np_utils

# %%
x1 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_1.npy')
print(x1.shape)
y1 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_1.npy')
print(y1.shape)
x2 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_2.npy')
print(x2.shape)
y2 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_2.npy')
print(y2.shape)
x3 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_3.npy')
print(x3.shape)
y3 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_3.npy')
print(y3.shape)
x4 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_4.npy')
print(x4.shape)
y4 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_4.npy')
print(y4.shape)
x5 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_5.npy')
print(x5.shape)
y5 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_5.npy')
print(y5.shape)
x6 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_6.npy')
print(x6.shape)
y6 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_6.npy')
print(y6.shape)
x7 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_7.npy')
print(x7.shape)
y7 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_7.npy')
print(y7.shape)
x8 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_8.npy')
print(x8.shape)
y8 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_8.npy')
print(y8.shape)
x9 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_9.npy')
print(x9.shape)
y9 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_9.npy')
print(y9.shape)
x10 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_10.npy')
print(x10.shape)
y10 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_10.npy')
print(y10.shape)
x11 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_11.npy')
print(x11.shape)
y11 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_11.npy')
print(y11.shape)
x12 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_12.npy')
print(x12.shape)
y12 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_12.npy')
print(y12.shape)
x13 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_13.npy')
print(x13.shape)
y13 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_13.npy')
print(y13.shape)
x14 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_14.npy')
print(x14.shape)
y14 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_14.npy')
print(y14.shape)
x15 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_15.npy')
print(x15.shape)
y15 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_15.npy')
print(y15.shape)
x16 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_16.npy')
print(x16.shape)
y16 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_16.npy')
print(y16.shape)
x17 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_17.npy')
print(x17.shape)
y17 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_17.npy')
print(y17.shape)
x18 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_18.npy')
print(x18.shape)
y18 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_18.npy')
print(y18.shape)
x19 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_19.npy')
print(x19.shape)
y19 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_19.npy')
print(y19.shape)
x20 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_20.npy')
print(x20.shape)
y20 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_20.npy')
print(y20.shape)
x21 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_21.npy')
print(x21.shape)
y21 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_21.npy')
print(y21.shape)
x22 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_22.npy')
print(x22.shape)
y22 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_22.npy')
print(y22.shape)
x23 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_23.npy')
print(x23.shape)
y23 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_23.npy')
print(y23.shape)
x24 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_24.npy')
print(x24.shape)
y24 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_24.npy')
print(y24.shape)
x25 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_25.npy')
print(x25.shape)
y25 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_25.npy')
print(y25.shape)
x26 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_26.npy')
print(x26.shape)
y26 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_26.npy')
print(y26.shape)
x27 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_27.npy')
print(x27.shape)
y27 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_27.npy')
print(y27.shape)
x28 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_28.npy')
print(x28.shape)
y28 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_28.npy')
print(y28.shape)
x29 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_29.npy')
print(x29.shape)
y29 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_29.npy')
print(y29.shape)
x30 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_30.npy')
print(x30.shape)
y30 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_30.npy')
print(y30.shape)
x31 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_31.npy')
print(x31.shape)
y31 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_31.npy')
print(y31.shape)
x32 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_32.npy')
print(x32.shape)
y32 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_32.npy')
print(y32.shape)
x33 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_33.npy')
print(x33.shape)
y33 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_33.npy')
print(y33.shape)
x34 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_34.npy')
print(x34.shape)
y34 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_34.npy')
print(y34.shape)
x35 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_35.npy')
print(x35.shape)
y35 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_35.npy')
print(y35.shape)
x36 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_36.npy')
print(x36.shape)
y36 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_36.npy')
print(y36.shape)
x37 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_37.npy')
print(x37.shape)
y37 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_37.npy')
print(y37.shape)
x38 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_38.npy')
print(x38.shape)
y38 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_38.npy')
print(y38.shape)
x39 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_39.npy')
print(x39.shape)
y39 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_39.npy')
print(y39.shape)
x40 = np.load('/Users/wildflowerlyi/Desktop/x_augmentation_array_mean_beta_largesample_40.npy')
print(x40.shape)
y40 = np.load('/Users/wildflowerlyi/Desktop/y_augmentation_array_mean_beta_largesample_40.npy')
print(y40.shape)

# %%
x_mean_beta_largesample_full = np.concatenate((x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,
                                              x16,x17,x18,x19,x20,x21,x22,x23,x24,x25,x26,x27,
                                              x28,x29,x30,x31,x32,x33,x34,x35,x36,x37,x38,x39,x40), axis=0)
y_mean_beta_largesample_full = np.concatenate((y1,y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12,y13,y14,y15,
                                              y16,y17,y18,y19,y20,y21,y22,y23,y24,y25,y26,y27,
                                              y28,y29,y30,y31,y32,y33,y34,y35,y36,y37,y38,y39,y40), axis=0)

np.save(OUT_DIR + '/' + 'x_augmentation_array_mean_beta_largesample_full', x_mean_beta_largesample_full) #LEILAEDIT for .npy saving
np.save(OUT_DIR + '/' + 'y_augmentation_array_mean_beta_largesample_full', y_mean_beta_largesample_full) #LEILAEDIT for .npy saving
